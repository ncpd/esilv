# %% [markdown]
# # 01: Introduction and Visualisation

# %% [markdown]
# Jupyter **cheat-sheet**: https://www.cheatography.com/weidadeyue/cheat-sheets/jupyter-notebook/

# %% [markdown]
# ## Importing fundamental packages

# %% [markdown]
# ### NumPy
#   * Package for fast "scientific" computing (especially linear algebra and random numbers capabilities).
#   * Mostly an interface to fast C/C++/Fortran libraries.
#   * http://www.numpy.org/
#
# ### pandas
#   * Popular data analysis toolkit.
#   * Helps to easily manipulate with **tabular** data.
#   * http://pandas.pydata.org/
#
# ### scikit-learn (sklearn)
#   * Data science tools and methods in Python.
#   * Built on NumPy, [SciPy](https://www.scipy.org/), and matplotlib
#   * http://scikit-learn.org/stable/
#
# ### matplotlib
#   * Fundamental 2D plotting library.
#   * https://matplotlib.org/
#
# ### seaborn
#   * Data visualisation tool based on matplotlib.
#   * https://seaborn.pydata.org/

# %%
import numpy as np
import pandas as pd
import sklearn as skit
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Basic data manipulations using pandas
#
#   - Load data1.csv and data2.csv using pandas.
#   - Find out types of data in all columns (do they contain strings, numbers, ...? And how variable are these?)

# %% [markdown]
# ### Loading data
#
#   - Load data from the csv files to the pandas DataFrame.

# %%
data1 = pd.read_csv('data1.csv')
data2 = pd.read_csv('data2.csv',sep=';')

# %% [markdown]
# ### Using pandas functions to get a basic overview of a dataset

# %%
#display(data1.head())
#data2.head()
#data1.info()
#data1.describe()
#data1.isnull().sum()
#display(df.head())
#data1.head()

# %% [markdown]
# ### Basics of data selection

# %%
#data1['Age'] # the collumn with pandas.Series.name = 'Age'
#data1.Age # dtto
#data1['Age'][:10] # get first 10 entries of the column Age
#data1['Age'][:3][[True, False, True]]
#data1['Age'] > 30 # applying condition on on all entries of the series -> series containg the results (True/False)
#data1[(data1.Age > 30) & (data1.Survived == 1)] # series containing only people older that 30
#data1[['Age', 'Survived']].head() # selecting only given columns
#data1_tmp = data1.copy() # make a deep copy of the dataframe
#data1_tmp.columns = range(12) # renaming columns
#display(data1_tmp.head())
#data1_tmp.head()
#data1.iloc[1,0:2] # geting the first row
#data1.loc[1,['Age', 'Sex']] # indexer (see .loc? and .iloc?)
#data.head()

# %% [markdown]
# ## Task 01: Concatenating data
#
#   - Append data2.csv to data1.csv:
#       - Data (columns) not present in data1.csv are omitted from data2.csv.
#       - Calculate the Age using the BirthYear column in data2.csv and append the result to the Age column of data1.
#       - PasangerId must be unique in the resulting data frame.
#       - Use pandas.concat method.

# %%
data2_tmp=data2.copy()
data2_tmp['Age'] = 1912 - data2_tmp.BirthYear
data2_tmp.PassengerId += 10000
data = pd.concat([data1, data2_tmp], ignore_index=True, join="inner")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Plotting with pandas and seaborn

# %%
import matplotlib.pyplot as plt # standard convention for importing the plotting tool
import matplotlib
# %matplotlib inline
matplotlib.style.use('ggplot')

# %% [markdown]
# ### Influence of Pclass, Age and Sex on passangers chances

# %%
#data.plot() # default behaviour of the plot() method
# look especially on what kinds of plots are available:
#data.plot?

# get data frames for survived and not-survived passangers
survived = data[data['Survived'] == 1]
not_survived = data[data['Survived'] == 0]

ax = survived.plot.scatter(x='Age', y='Pclass', color='Green', label='Survived')
not_survived.plot(x='Age', y='Pclass', kind='scatter', color='Black', label='Not Survived')
# plot the graphs into one figure:
not_survived.plot.scatter(x='Age', y='Pclass', color='Black', label='Not Survived', ax = ax)

# %%
plt.figure(figsize=(9,12)) # figsize in inches
plt.subplot(321) # three rows and two columns, put the following plot into the first slot
plt.xlabel('Age')
plt.ylim((0,160))
survived['Age'].plot.hist(color='Green')
plt.subplot(322)
plt.ylim((0,160))
plt.xlabel('Age')
not_survived['Age'].plot.hist(color='Black')
plt.subplot(323)
plt.ylim((0,370))
plt.xlabel('Pclass')
survived['Pclass'].plot.hist(color='Green')
plt.subplot(324)
plt.ylim((0,370))
plt.xlabel('Pclass')
not_survived['Pclass'].plot.hist(color='Black')
plt.subplot(325)
plt.ylim((0,480))
plt.xlabel('Sex')
survived['Sex'].apply(lambda x: 1 if x == 'female' else 0).plot.hist(color='Green')
plt.subplot(326)
plt.ylim((0,480))
plt.xlabel('Sex')
not_survived['Sex'].apply(lambda x: 1 if x == 'female' else 0).plot.hist(color='Black')

# %% [markdown]
# ## Seaborne: investigating relations between features

# %%
plt.figure(figsize=(14,12))
data['Sex'] = data['Sex'].apply(lambda x: 1 if x == 'female' else 0)
cor_matrix = data.drop('PassengerId', axis=1).corr()
print(cor_matrix)
sns.heatmap(cor_matrix, annot=True)
# Out:
#           Survived    Pclass       Sex       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481  0.543351 -0.077128 -0.035322  0.081629 -0.027145
# Pclass   -0.338481  1.000000 -0.131900 -0.369388  0.083081  0.018443  0.084197
# Sex       0.543351 -0.131900  1.000000 -0.093223  0.114631  0.245489  0.026989
# Age      -0.077128 -0.369388 -0.093223  1.000000 -0.308126 -0.189056 -0.104007
# SibSp    -0.035322  0.083081  0.114631 -0.308126  1.000000  0.414838  0.116760
# Parch     0.081629  0.018443  0.245489 -0.189056  0.414838  1.000000  0.159925
# Fare     -0.027145  0.084197  0.026989 -0.104007  0.116760  0.159925  1.000000

# %% [markdown]
# ## Task 02: scatter plots for all pairs of features
#
#   - Use sns.pairplot method to get the plots analogous to the one below for all (reasonable) pairs of features. Explain what you see :).

# %%
plt.figure(figsize=(12,4))
sns.stripplot(x="Pclass", y="Age", hue="Survived", data=data, palette= ['red','green'], jitter=True) # add

# %%
### your code goes here

# %% [markdown]
# ## Web scrapping with Python and pandas (1st homework)
#
# ### Tips:
#    - Use `import requests` to get HTML sourse of a given `url`:
#       - `r = requests.get(url)`
#       - `html = r.text`
#    - Use `pandas.read_html(r.text)` to save content of all `<table>`'s as pandas DataFrames:
#       - `list_of_data_frames = pd.read_html(html,flavor='html5lib')`
#    - Use `from bs4 import BeautifulSoup` for html parsing.

# %%
import requests as requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Example of simple web scrapping
#
# The aim is to download all data availale here (http://kap.ujak.cz/index.php) and store them in pandas DataFrame.

# %%
# url with search form
url = 'http://kap.ujak.cz/index.php?strana={}'
# setting POST variables to simulate (use developer mode of your browser)
data = {
    'typ' : 'kap',
    'prace' : 'BP', # DP = diplomka, DR = disertace, RI = rigorozní
    'nazev' : '%%%', # alespoň tři písmena z názvu hledané práce
    'pocet' : '0',
    'klic' : '', # alespoň tři písmena z klíčových slov
    'kl' : 'c', # c = částečně odpovídá, n = plně odpovídá
    'hledat' : 'Vyhledat'
}

data_all = pd.DataFrame()
for prace in ['BP', 'DP']:
    data['prace'] = prace
    r = requests.post(url, data)
    r.encoding='cp1250'
    ldf = pd.read_html(r.text,flavor='html5lib', header=0)
    df = ldf[0]
    strana = 30
    if data_all.shape[0] == 0:
        data_all = df.copy()
    else:
        data_all = pd.concat([data_all,df], ignore_index=True)
    while df.shape[0] > 0:
        if data_all.shape[0] > 200: # just to prevent from downloading all data
            break
        print(url.format(strana))
        r = requests.post(url.format(strana), data)
        r.encoding='cp1250'
        ldf = pd.read_html(r.text,flavor='html5lib', header=0)
        df = ldf[0]
        strana = strana + 30
        data_all = pd.concat([data_all,df], ignore_index=True)
display(data_all)
# Out:
# http://kap.ujak.cz/index.php?strana=30
# http://kap.ujak.cz/index.php?strana=60
# http://kap.ujak.cz/index.php?strana=90
# http://kap.ujak.cz/index.php?strana=120
# http://kap.ujak.cz/index.php?strana=150
# http://kap.ujak.cz/index.php?strana=180
#                         Autor  \
# 0        Abdrakhmanova Aizhan
# 1            Abdullayev Timur
# 2     Abdussattarov Nursultan
# 3               Ábelová Šárka
# 4        Abrahámová Jaroslava
# 5           Abrahámová Simona
# 6               Abrhámová Eva
# 7                Abrman Milan
# 8              Abtová Martina
# 9           Abu - Rabia Maher
# 10          Abu-Serriah Lucie
# 11          Ackahová Hajnalka
# 12                    Acs Ivo
# 13                   Adam Jan
# 14            Adamcová Dagmar
# 15   Adamcová Mohrová Adriana
# 16           Adamcová Pavlína
# 17          Adamcová Veronika
# 18             Adamčík Martin
# 19             Adamčík Michal
# 20            Adamčíková Jana
# 21          Adamčíková Monika
# 22         Adamčíková Pavlína
# 23              Adamec Michal
# 24           Adámek František
# 25           Adamenková Irena
# 26         Adamíková Kateřina
# 27              Adámková Jana
# 28             Adámková Marta
# 29           Adámková Martina
# ..                        ...
# 210            Abdyrov Kairat
# 211             Ábelová Šárka
# 212               Aberle Jiří
# 213           Abíková Tatiana
# 214      Abrahámová Jaroslava
# 215          Abrahamová Marie
# 216             Abrhámová Eva
# 217              Abrman Milan
# 218        Absolonová Jarmila
# 219         Abu-Serriah Lucie
# 220                Adam Marek
# 221            Adamcová Mária
# 222            Adamcová Mária
# 223          Adamcová Mariana
# 224          Adamcová Markéta
# 225            Adamcová Šárka
# 226            Adamčík Martin
# 227           Adamčíková Jana
# 228         Adamčíková Monika
# 229             Adamec Michal
# 230              Adamec Roman
# 231           Adamečková Lada
# 232         Adamičková Blanka
# 233        Adamičková Markéta
# 234        Adámiková Katarína
# 235           Adámková Tereza
# 236            Adamová Denisa
# 237              Adamová Jana
# 238         Adamová Magdaléna
# 239             Adamová Pavla
#
#                                            Název práce  \
# 0            Vliv médií na děti a mládež v Kazachstánu
# 1         Inflation: Kazakhstani and global tendencies
# 2    Payment system od Kazakhstan: modern condition...
# 3    Rovné příležitosti mužů a žen na trhu práce (Z...
# 4           Nekalá soutěž v aplikační praxi soudů v ČR
# 5              Výchova dítěte v patologickém prostředí
# 6           Vliv rodiny na zdravý duševní vývoj dítěte
# 7    Specifické vývojové poruchy školních dovednost...
# 8    Bezbariérové chodníky pro osoby se sníženou sc...
# 9     Porovnávání logopedických systémů v Izraeli a ČR
# 10                    Úřad práce a jeho sociální klima
# 11             Syndrom Burn - out u pečujících profesí
# 12                  Okolnosti vylučující protiprávnost
# 13                Výchova a vzdělávání dětí s autismem
# 14   Výhody výpočetní techniky v logopedické interv...
# 15   Gender mainstreaming problematika návratnosti ...
# 16   Metodika tvorby zpravodajských a publicistický...
# 17   Možnosti vzdělávání a integrace dětí s mozkovo...
# 18                            E-learning ve vzdělávání
# 19               Právní stát v minulosti a současnosti
# 20     Syndrom vyhoření v oblasti pomáhajících profesí
# 21   Psychologické aspekty sociálnej integrácie jed...
# 22                                 Nájem věcí movitých
# 23             Podíl rodiny v etiologii poruch chování
# 24        Možnosti vzdělávání žen na mateřské dovolené
# 25     Agresivita jako psychologický problém osobnosti
# 26                                     Pěstounská péče
# 27   Ideologické pojetí televizního zpravodajství v...
# 28   Systém vzdělávání zaměstnanců v české justici ...
# 29                       Územní samosprávné celky v ČR
# ..                                                 ...
# 210  Právo na vzdělání a jeho realizace v Kazachstá...
# 211  Vzdělávání lidí stižených sociální exkluzí s d...
# 212  Systém firemního vzdělávání u Policie České re...
# 213          Násilie v rodine z pohľadu detí a mládeže
# 214  Minulost, přítomnost a perspektivy nájemního b...
# 215                Etické s právní aspekty v lékařství
# 216      Syndrom CAN a jeho psychosociální souvislosti
# 217  Využití arteterapie jako diagnostického prostř...
# 218  Vzdělávání zaměstnanců veřejné správy a samosp...
# 219  Vývoj migračních trendů v České republice a Ve...
# 220                                      Domácí násilí
# 221  Dieťa s mentálnym postihnutím vo výchovno-vzde...
# 222  Dieťa s Downovým syndrómom vo výchovno-vzdeláv...
# 223    Nezamestnanosť a jej sociálnopatologické riziká
# 224  Analýza a perspektivy jazykového vzdělávání do...
# 225  Žiakl so špeciálnymi poruchami učenia v bežnom...
# 226  Mentorování štábních struktur vojsk Afgánské n...
# 227  Problematika sociálně patologických jevů ve vz...
# 228              Kvalita života jedincov s postihnutím
# 229  Vliv rodiny na hierarchii hodnot a chování dítěte
# 230  Komplexní analýza kompetencí vedoucích zaměstn...
# 231  Studenti jako cílová skupina marketingových ka...
# 232  Historie vzniku a vývoje českého internetu a j...
# 233        Syndrom vyhoření u pedagogických pracovníků
# 234  Hyperaktívne dieťa vo výchovno - vzdelávacom p...
# 235  Analýza sytému odměňování ve vybrané organizac...
# 236                  Metody a formy výběru zaměstnanců
# 237       Jak motivovat žáka III. Třídy základní školy
# 238  Získavanie a výber zamestnancov ako súčasť str...
# 239  Výuka anglického jazyka na základní škole prak...
#
#                                     Vedoucí   Rok Typ práce
# 0         Svobodová Alena, Doc. PhDr.; CSc.  2017        BP
# 1            Vacenovský Michal, Ing.; LL.M.  2011        BP
# 2            Vacenovský Michal, Ing.; LL.M.  2011        BP
# 3               Vacínová Marie, PhDr.; CSc.  2007        BP
# 4    Rákosník Jakub, Doc. PhDr. JUDr; Ph.D.  2008        BP
# 5               Farková Blanka, Mgr.; Ph.D.  2011        BP
# 6                     Tomko Anton, PaedDr.;  2011        BP
# 7                        Duksová Iva, Mgr.;  2012        BP
# 8                   Dostálová Radana, Mgr.;  2011        BP
# 9         Klugerová Jarmila, PaedDr.; Ph.D.  2010        BP
# 10               Noveská Izabela, Mgr.; MBA  2014        BP
# 11              Farková Marie, PhDr.; Ph.D.  2005        BP
# 12                        Černý Jan, JUDr.;  2015        BP
# 13                      Novotná Kateřina, ;  2007        BP
# 14           Melicharová Jana, PhDr.; Ph.D.  2017        BP
# 15                 Petrášek Josef, PaedDr.;  2014        BP
# 16                   Šesták Oldřich, PhDr.;  2008        BP
# 17                 Bürgerová Martina, Mgr.;  2016        BP
# 18                Nespěšný David, Ing. Bc.;  2011        BP
# 19      Masopust Zdeněk, JUDr. PhDr.; DrSc.  2011        BP
# 20           Karkošová Martina, Mgr.; Ph.D.  2010        BP
# 21           Čajka Kornel, Doc. PhDr.; CSc.  2013        BP
# 22                     Doležal Adam, JUDr.;  2011        BP
# 23                      Toman Jan, PaedDr.;  2008        BP
# 24      Veteška Jaroslav, Doc. PhDr.; Ph.D.  2009        BP
# 25              Vacínová Marie, PhDr.; CSc.  2007        BP
# 26                 Holaňová Michaela, Mgr.;  2011        BP
# 27                      Verner Pavel, Mgr.;  2011        BP
# 28                   Koňarik Jan, Ing.; MBA  2016        BP
# 29                Zpěvák Aleš, JUDr.; Ph.D.  2013        BP
# ..                                      ...   ...       ...
# 210         Brynda Zdeněk, Doc. JUDr.; CSc.  2008        DP
# 211                   Tomko Anton, PaedDr.;  2009        DP
# 212                 Urbanovský Jana, PhDr.;  2012        DP
# 213                    Nagyová Anna, PhDr.;  2009        DP
# 214  Rákosník Jakub, Doc. PhDr. JUDr; Ph.D.  2012        DP
# 215                   Vašinová Petra, Mgr.;  2013        DP
# 216         Presslerová Pavla, PhDr.; Ph.D.  2013        DP
# 217            Fišerová Zuzana, Mgr.; Ph.D.  2014        DP
# 218           Mrhač Josef, Doc. PhDr.; CSc.  2009        DP
# 219        Havlík Radomír, Doc. PhDr.; CSc.  2016        DP
# 220           Vacínová Tereza, PhDr.; Ph.D.  2009        DP
# 221                Rašinová Viola, PaedDr.;  2015        DP
# 222            Štefková Denisa, Mgr.; Ph.D.  2012        DP
# 223             Španková Jana, PhDr.; Ph.D.  2011        DP
# 224        Fialová Ludmila, Doc. Dr.; Ph.D.  2008        DP
# 225             Španková Jana, PhDr.; Ph.D.  2012        DP
# 226                      Klen Štěpán, Mgr.;  2014        DP
# 227                Rašinová Viola, PaedDr.;  2015        DP
# 228            Hejdiš Milan, PaedDr.; Ph.D.  2015        DP
# 229                     Toman Jan, PaedDr.;  2010        DP
# 230          Barták Jan, Prof. PhDr.; DrSc.  2007        DP
# 231                  Hanáčková Lenka, Ing.;  2013        DP
# 232                     Verner Pavel, Mgr.;  2010        DP
# 233       Kodým Miloslav, Prof. PhDr.; CSc.  2014        DP
# 234            Štefková Denisa, Mgr.; Ph.D.  2011        DP
# 235  Rákosník Jakub, Doc. PhDr. JUDr; Ph.D.  2013        DP
# 236          Barták Jan, Prof. PhDr.; DrSc.  2006        DP
# 237                 Kreuzová Renata, PhDr.;  2011        DP
# 238                 Urbanovský Jana, PhDr.;  2012        DP
# 239                Petelíková Lenka, PhDr.;  2013        DP
#
# [240 rows x 5 columns]

# %%
dataUJAK = pd.read_csv('ujak.csv', index_col=0)
display(dataUJAK.head())
dataUJAK[dataUJAK['Rok'] > 2000].groupby(['Název práce']).size().sort_values(ascending=False)
# Out:
#                      Autor                                        Název práce  \
# 0     Abdrakhmanova Aizhan          Vliv médií na děti a mládež v Kazachstánu
# 1         Abdullayev Timur       Inflation: Kazakhstani and global tendencies
# 2  Abdussattarov Nursultan  Payment system od Kazakhstan: modern condition...
# 3            Ábelová Šárka  Rovné příležitosti mužů a žen na trhu práce (Z...
# 4     Abrahámová Jaroslava         Nekalá soutěž v aplikační praxi soudů v ČR
#
#                                   Vedoucí   Rok Typ práce
# 0       Svobodová Alena, Doc. PhDr.; CSc.  2017        BP
# 1          Vacenovský Michal, Ing.; LL.M.  2011        BP
# 2          Vacenovský Michal, Ing.; LL.M.  2011        BP
# 3             Vacínová Marie, PhDr.; CSc.  2007        BP
# 4  Rákosník Jakub, Doc. PhDr. JUDr; Ph.D.  2008        BP
# Název práce
# Mezilidské vztahy na pracovišti                                                         56
# Vliv rodiny na zdravý duševní vývoj dítěte                                              51
# Domácí násilí                                                                           33
# Specifické poruchy učení                                                                32
# Kvalita života seniorů                                                                  31
# Syndrom vyhoření                                                                        28
# Vzdělávání seniorů                                                                      28
# Systém vzdělávání a rozvoj lidských zdrojů v organizaci                                 27
# Vedení týmu                                                                             27
# Motivace, hodnocení a odměňování pracovníků v organizaci                                25
# Dieťa postihnuté autizmom - možnosti výchovy a vzdelávania                              24
# Psychologie reklamy                                                                     23
# Emoční inteligence a možnosti jejího rozvoje                                            21
# Motivace zaměstnanců jako nástroj dosažení cíle                                         20
# Motivace zaměstnanců                                                                    19
# Firemní vzdělávání                                                                      19
# Šikana na pracovišti                                                                    19
# Poruchy příjmu potravy                                                                  19
# Vliv patogenního rodinného prostředí na rozvoj osobnosti dítěte                         19
# Nezaměstnanost jako sociální problém                                                    18
# Syndrom vyhoření v pomáhajících profesích                                               18
# Vlastní téma                                                                            18
# Kriminalita mládeže                                                                     18
# Drogy a drogová závislosť u mládeže                                                     18
# Drogové závislosti u dospívajících                                                      16
# Agresivita jako psychologický problém osobnosti                                         16
# Získávání a výběr pracovníků v organizaci                                               16
# Firemní kultura                                                                         15
# Drogy a drogová závislost u mládeže                                                     15
# Logopedická péče o dítě s koktavostí                                                    15
#                                                                                         ..
# Sociální práce v penitenciárním prostředí                                                1
# Sociální práce ve středověku                                                             1
# Sociální práva - historický vývoj, základní dokumenty a jejich ochrana v současné EU     1
# Sociální péče o seniory v České republice                                                1
# Sociální práce s cizinci v Záchytném zařízení pro cizince Bělá-Jezová                    1
# Sociální práce na obecních úřadech od 1.1.2012                                           1
# Sociální patologie - prostituce                                                          1
# Sociální práce kurátora pro mládež u klientů s psychiatrickou diagnózou                  1
# Sociální patologie dnešní mládeže                                                        1
# Sociální patologie se zaměřením na prostituci                                            1
# Sociální percepce                                                                        1
# Sociální percepce ve vybraných personálních situacích                                    1
# Sociální podnikání v tržním hospodářství                                                 1
# Sociální pojištění samostatně výdělečně činné osoby                                      1
# Sociální politika a podniková sociální politika                                          1
# Sociální politika státu                                                                  1
# Sociální politika v České republice                                                      1
# Sociální pomoc v systému sociálního zabezpečení                                          1
# Sociální poruchy dospívájících dívek                                                     1
# Sociální pozice stáří v naší společnosti                                                 1
# Sociální pracovnice v systému zacházení s drogově závislými vězni                        1
# Sociální pracovník - Syndrom vyhoření a prevence proti němu                              1
# Sociální pracovník a syndrom vyhoření                                                    1
# Sociální pracovník v roli vedoucího týmu klíčových pracovníků v domově pro seniory       1
# Sociální prevence a neintencionální výchova mládeže v Šluknovském regionu                1
# Sociální profil pracovníků týmu a jejich rozvoj                                          1
# Sociální prostředí a jazyk                                                               1
# Sociální prostředí ve vztahu k dalšímu vzdělávání                                        1
# Sociální práce a úloha sociálního pracovníka v oblasti penitenciární péče                1
# " Zpověď " jako zdroj poznání životní pouti člověka                                      1
# Length: 26624, dtype: int64
